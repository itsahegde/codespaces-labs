# %%
import pandas as pd

# %%
df = pd.Series([78, 85, 92, 67, 88])

# %%
df
# Out:
# 0    78
# 1    85
# 2    92
# 3    67
# 4    88
# dtype: int64

# %%
df.values
# Out:
# array([78, 85, 92, 67, 88])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.dtypes
# Out:
# dtype('int64')

# %%
df.mean
# Out:
# <bound method Series.mean of 0    78
# 1    85
# 2    92
# 3    67
# 4    88
# dtype: int64>

# %%
df.mean()
# Out:
# np.float64(82.0)

# %%
df.max()
# Out:
# np.int64(92)

# %%
df.min()
# Out:
# np.int64(67)

# %%
data = {
    "Student": ["Asha", "Ravi", "Meena", "Kiran", "Arun"],
    "Marks": [85, 78, 92, 74, 88]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Student  Marks
# 0    Asha     85
# 1    Ravi     78
# 2   Meena     92
# 3   Kiran     74
# 4    Arun     88

# %%
df.set_index('Student', inplace=True)

# %%
df.loc["Meena", "Marks"]
# Out:
# np.int64(92)

# %%
data = {
    "Student": ["Asha", "Ravi", "Meena", "Kiran", "Arun"],
    "Marks": [85, 78, 92, 74, 88],
    "Age": [22, 23, 21, 24, 22],
    "Department": ["CSE", "ECE", "CSE", "ME", "ECE"]
}

# %%
df = pd.DataFrame(data)
df.set_index("Student", inplace=True)

# %%
df
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Ravi        78   23        ECE
# Meena       92   21        CSE
# Kiran       74   24         ME
# Arun        88   22        ECE

# %%
df.head(3)
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Ravi        78   23        ECE
# Meena       92   21        CSE

# %%
df.tail(2)
# Out:
#          Marks  Age Department
# Student
# Kiran       74   24         ME
# Arun        88   22        ECE

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Marks', 'Age', 'Department'], dtype='str')

# %%
df.dtypes
# Out:
# Marks         int64
# Age           int64
# Department      str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, Asha to Arun
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Marks       5 non-null      int64
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 160.0+ bytes

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   83.400000  22.400000
# std     7.334848   1.140175
# min    74.000000  21.000000
# 25%    78.000000  22.000000
# 50%    85.000000  22.000000
# 75%    88.000000  23.000000
# max    92.000000  24.000000

# %%
df.shape[0]
# Out:
# 5

# %%
df.shape[1]
# Out:
# 3

# %%
df.Age
# Out:
# Student
# Asha     22
# Ravi     23
# Meena    21
# Kiran    24
# Arun     22
# Name: Age, dtype: int64

# %%
df.index
# Out:
# Index(['Asha', 'Ravi', 'Meena', 'Kiran', 'Arun'], dtype='str', name='Student')

# %%
df.Marks
# Out:
# Student
# Asha     85
# Ravi     78
# Meena    92
# Kiran    74
# Arun     88
# Name: Marks, dtype: int64

# %%
df.iloc[0]
# Out:
# Marks          85
# Age            22
# Department    CSE
# Name: Asha, dtype: object

# %%
df.iloc[3]
# Out:
# Marks         74
# Age           24
# Department    ME
# Name: Kiran, dtype: object

# %%
df.iloc[0:2]
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Ravi        78   23        ECE

# %%
df.iloc[0:3]
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Ravi        78   23        ECE
# Meena       92   21        CSE

# %%
df.loc[:, 'Marks']
# Out:
# Student
# Asha     85
# Ravi     78
# Meena    92
# Kiran    74
# Arun     88
# Name: Marks, dtype: int64

# %%
df[df['Marks']>80]
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Meena       92   21        CSE
# Arun        88   22        ECE

# %%
df[(df['Marks']>75) & (df['Marks']<80)]
# Out:
#          Marks  Age Department
# Student
# Ravi        78   23        ECE

# %%
df[df['Department']=='CSE']
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Meena       92   21        CSE

# %%
df[(df['Marks']>80) & (df['Department']=='CSE')]
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Meena       92   21        CSE

# %%
df[(df['Department']=='ECE') | (df['Department']=='CSE')]
# Out:
#          Marks  Age Department
# Student
# Asha        85   22        CSE
# Ravi        78   23        ECE
# Meena       92   21        CSE
# Arun        88   22        ECE

# %%
import numpy as np

# %%
df['Result'] = np.where(df['Marks']>75, 'Pass', 'Fail')

# %%
df
# Out:
#          Marks  Age Department Result
# Student
# Asha        85   22        CSE   Pass
# Ravi        78   23        ECE   Pass
# Meena       92   21        CSE   Pass
# Kiran       74   24         ME   Fail
# Arun        88   22        ECE   Pass

# %%
conditions = [df['Marks']>=90, df['Marks']>=80, df['Marks']>=70]

# %%
choices = ['A', 'B', 'C']

# %%
df['Grades'] = np.select(conditions, choices, default='D')

# %%
df
# Out:
#          Marks  Age Department Result Grades
# Student
# Asha        85   22        CSE   Pass      B
# Ravi        78   23        ECE   Pass      C
# Meena       92   21        CSE   Pass      A
# Kiran       74   24         ME   Fail      C
# Arun        88   22        ECE   Pass      B

# %%
df.sort_values(by='Marks')
# Out:
#          Marks  Age Department Result Grades
# Student
# Kiran       74   24         ME   Fail      C
# Ravi        78   23        ECE   Pass      C
# Asha        85   22        CSE   Pass      B
# Arun        88   22        ECE   Pass      B
# Meena       92   21        CSE   Pass      A

# %%
df.sort_values(by='Marks', ascending=False)
# Out:
#          Marks  Age Department Result Grades
# Student
# Meena       92   21        CSE   Pass      A
# Arun        88   22        ECE   Pass      B
# Asha        85   22        CSE   Pass      B
# Ravi        78   23        ECE   Pass      C
# Kiran       74   24         ME   Fail      C

# %%
df.sort_values(by=['Marks','Department'], ascending=True)
# Out:
#          Marks  Age Department Result Grades
# Student
# Kiran       74   24         ME   Fail      C
# Ravi        78   23        ECE   Pass      C
# Asha        85   22        CSE   Pass      B
# Arun        88   22        ECE   Pass      B
# Meena       92   21        CSE   Pass      A

# %%
data = {
    "Name": ["Asha", "Ravi", "Meena", "Kiran", "Arun"],
    "Age": [22, 23, np.nan, 24, 22],
    "Marks": [85, np.nan, 92, 74, 88]
}

# %%
students = pd.DataFrame(data)

# %%
students.shape
# Out:
# (5, 3)

# %%
students.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# dtype: int64

# %%
students[students.isna().any(axis=1)]
# Out:
#     Name   Age  Marks
# 1   Ravi  23.0    NaN
# 2  Meena   NaN   92.0

# %%
students.drop_duplicates()
# Out:
#     Name   Age  Marks
# 0   Asha  22.0   85.0
# 1   Ravi  23.0    NaN
# 2  Meena   NaN   92.0
# 3  Kiran  24.0   74.0
# 4   Arun  22.0   88.0

# %%
stus = students.dropna()

# %%
stus
# Out:
#     Name   Age  Marks
# 0   Asha  22.0   85.0
# 3  Kiran  24.0   74.0
# 4   Arun  22.0   88.0

# %%
students.fillna(students.mean(numeric_only=True))
# Out:
#     Name    Age  Marks
# 0   Asha  22.00  85.00
# 1   Ravi  23.00  84.75
# 2  Meena  22.75  92.00
# 3  Kiran  24.00  74.00
# 4   Arun  22.00  88.00

# %%
data = {
    "Name": ["Asha", "Ravi", "Meena", "Asha", "Arun"],
    "Marks": [85, 78, 92, 85, 88]
}

# %%
df2 = pd.DataFrame(data)

# %%
df2[df2.duplicated(keep=False)]
# Out:
#    Name  Marks
# 0  Asha     85
# 3  Asha     85

# %%
df2.drop_duplicates()
# Out:
#     Name  Marks
# 0   Asha     85
# 1   Ravi     78
# 2  Meena     92
# 4   Arun     88

# %%
marks = pd.DataFrame({
    "Student": ["A", "B", "C", "D", "E"],
    "Marks": [78, 85, 92, 67, 88]
})

# %%
marks.shape
# Out:
# (5, 2)

# %%
marks['Marks'].mean()
# Out:
# np.float64(82.0)

# %%
marks.min()
# Out:
# Student     A
# Marks      67
# dtype: object

# %%
marks.max()
# Out:
# Student     E
# Marks      92
# dtype: object

# %%
marks['Marks'].median()
# Out:
# np.float64(85.0)

# %%
marks['Marks'].sum()
# Out:
# np.int64(410)

# %%
marks['Marks'].std()
# Out:
# np.float64(9.82344135219425)

# %%
data = {
    "Name": [
        "Asha", "Ravi", "Meena",
        "Kiran", "Arun", "Divya"
    ],

    "Department": [
        "CSE", "ECE", "CSE",
        "ME", "ECE", "CSE"
    ],

    "Marks": [
        85, 78, 92,
        74, 88, 80
    ]
}

df = pd.DataFrame(data)

# %%
df.groupby("Department")['Marks'].mean()
# Out:
# Department
# CSE    85.666667
# ECE    83.000000
# ME     74.000000
# Name: Marks, dtype: float64

# %%
df.groupby("Department")['Marks'].max()
# Out:
# Department
# CSE    92
# ECE    88
# ME     74
# Name: Marks, dtype: int64

# %%
df.groupby("Department")['Marks'].count()
# Out:
# Department
# CSE    3
# ECE    2
# ME     1
# Name: Marks, dtype: int64

# %%
df.groupby("Department")['Marks'].min()
# Out:
# Department
# CSE    80
# ECE    78
# ME     74
# Name: Marks, dtype: int64

# %%
students = pd.DataFrame({
    "StudentID": [101, 102, 103, 104],
    "Name": ["Asha", "Ravi", "Meena", "Kiran"]
})

marks = pd.DataFrame({
    "StudentID": [101, 102, 103, 104],
    "Marks": [85, 78, 92, 74]
})

# %%
merged_df = pd.merge(students, marks, on='StudentID')

# %%
merged_df
# Out:
#    StudentID   Name  Marks
# 0        101   Asha     85
# 1        102   Ravi     78
# 2        103  Meena     92
# 3        104  Kiran     74

# %%
data = {
    "Name": [
        "Asha", "Ravi", "Meena",
        "Kiran", "Arun", "Divya",
        "John", "Priya"
    ],

    "Department": [
        "CSE", "ECE", "CSE",
        "ME", "ECE", "CSE",
        "ME", "ECE"
    ],

    "Attendance": [
        92, 75, 96, 68,
        82, 88, 72, 95
    ],

    "Internal": [
        85, 72, 94, 65,
        80, 86, 70, 91
    ],

    "FinalMarks": [
        88, 74, 96, 62,
        83, 89, 68, 93
    ]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 0   Asha        CSE          92        85          88
# 1   Ravi        ECE          75        72          74
# 2  Meena        CSE          96        94          96
# 3  Kiran         ME          68        65          62
# 4   Arun        ECE          82        80          83
# 5  Divya        CSE          88        86          89
# 6   John         ME          72        70          68
# 7  Priya        ECE          95        91          93

# %%
df[:4]
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 0   Asha        CSE          92        85          88
# 1   Ravi        ECE          75        72          74
# 2  Meena        CSE          96        94          96
# 3  Kiran         ME          68        65          62

# %%
df[:5]
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 0   Asha        CSE          92        85          88
# 1   Ravi        ECE          75        72          74
# 2  Meena        CSE          96        94          96
# 3  Kiran         ME          68        65          62
# 4   Arun        ECE          82        80          83

# %%
df.shape
# Out:
# (8, 5)

# %%
df['FinalMarks'].mean()
# Out:
# np.float64(81.625)

# %%
df['FinalMarks'].mean()
# Out:
# np.float64(81.625)

# %%
df.loc[df['FinalMarks'].idxmax(), 'Name']
# Out:
# 'Meena'

# %%
df.loc[df['FinalMarks'].idxmin(), 'Name']
# Out:
# 'Kiran'

# %%
df[df['FinalMarks']>80]
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 0   Asha        CSE          92        85          88
# 2  Meena        CSE          96        94          96
# 4   Arun        ECE          82        80          83
# 5  Divya        CSE          88        86          89
# 7  Priya        ECE          95        91          93

# %%
df.groupby('Department')['FinalMarks'].mean()
# Out:
# Department
# CSE    91.000000
# ECE    83.333333
# ME     65.000000
# Name: FinalMarks, dtype: float64

# %%
df[df['Attendance']>80]
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 0   Asha        CSE          92        85          88
# 2  Meena        CSE          96        94          96
# 4   Arun        ECE          82        80          83
# 5  Divya        CSE          88        86          89
# 7  Priya        ECE          95        91          93

# %%
df.sort_values(by='FinalMarks')
# Out:
#     Name Department  Attendance  Internal  FinalMarks
# 3  Kiran         ME          68        65          62
# 6   John         ME          72        70          68
# 1   Ravi        ECE          75        72          74
# 4   Arun        ECE          82        80          83
# 0   Asha        CSE          92        85          88
# 5  Divya        CSE          88        86          89
# 7  Priya        ECE          95        91          93
# 2  Meena        CSE          96        94          96

# %%
df['Result']=np.where(df['FinalMarks']>=70, 'Pass', 'Fail')

# %%
df
# Out:
#     Name Department  Attendance  Internal  FinalMarks Result
# 0   Asha        CSE          92        85          88   Pass
# 1   Ravi        ECE          75        72          74   Pass
# 2  Meena        CSE          96        94          96   Pass
# 3  Kiran         ME          68        65          62   Fail
# 4   Arun        ECE          82        80          83   Pass
# 5  Divya        CSE          88        86          89   Pass
# 6   John         ME          72        70          68   Fail
# 7  Priya        ECE          95        91          93   Pass

# %%
conditions = [df['FinalMarks']>=90,df['FinalMarks']>=80, df['FinalMarks']>=70]
choices = ['Excellent', 'Very Good', 'Good']

df['Performance'] = np.select(conditions, choices, default='Needs Improvement')

# %%
df
# Out:
#     Name Department  Attendance  Internal  FinalMarks Result  \
# 0   Asha        CSE          92        85          88   Pass
# 1   Ravi        ECE          75        72          74   Pass
# 2  Meena        CSE          96        94          96   Pass
# 3  Kiran         ME          68        65          62   Fail
# 4   Arun        ECE          82        80          83   Pass
# 5  Divya        CSE          88        86          89   Pass
# 6   John         ME          72        70          68   Fail
# 7  Priya        ECE          95        91          93   Pass
#
#          Performance
# 0          Very Good
# 1               Good
# 2          Excellent
# 3  Needs Improvement
# 4          Very Good
# 5          Very Good
# 6  Needs Improvement
# 7          Excellent

# %%
df.groupby('Department')['FinalMarks'].max()
# Out:
# Department
# CSE    96
# ECE    93
# ME     68
# Name: FinalMarks, dtype: int64

# %%
employees = pd.DataFrame({
    "Employee": [
        "E01", "E02", "E03", "E04",
        "E05", "E06", "E07", "E08"
    ],

    "Department": [
        "IT", "HR", "IT", "Finance",
        "HR", "Finance", "IT", "Finance"
    ],

    "Experience": [
        5, 3, 7, 4,
        6, 8, 2, 5
    ],

    "Salary": [
        60000, 45000, 75000, 65000,
        55000, 85000, 48000, 70000
    ]
})

# %%
df = employees

# %%
df['Salary'].mean()
# Out:
# np.float64(62875.0)

# %%
df['Salary'].max()
# Out:
# np.int64(85000)

# %%
df['Salary'].min()
# Out:
# np.int64(45000)

# %%
df.loc[df['Salary'].idxmax(), 'Employee']
# Out:
# 'E06'

# %%
df[df['Salary']>60000]
# Out:
#   Employee Department  Experience  Salary
# 2      E03         IT           7   75000
# 3      E04    Finance           4   65000
# 5      E06    Finance           8   85000
# 7      E08    Finance           5   70000

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    73333.333333
# HR         50000.000000
# IT         61000.000000
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Experience'].mean()
# Out:
# Department
# Finance    5.666667
# HR         4.500000
# IT         4.666667
# Name: Experience, dtype: float64

# %%
df.groupby('Department').count()
# Out:
#             Employee  Experience  Salary
# Department
# Finance            3           3       3
# HR                 2           2       2
# IT                 3           3       3

# %%
df.sort_values(by='Salary')
# Out:
#   Employee Department  Experience  Salary
# 1      E02         HR           3   45000
# 6      E07         IT           2   48000
# 4      E05         HR           6   55000
# 0      E01         IT           5   60000
# 3      E04    Finance           4   65000
# 7      E08    Finance           5   70000
# 2      E03         IT           7   75000
# 5      E06    Finance           8   85000

# %%
df[df['Experience']>3]
# Out:
#   Employee Department  Experience  Salary
# 0      E01         IT           5   60000
# 2      E03         IT           7   75000
# 3      E04    Finance           4   65000
# 4      E05         HR           6   55000
# 5      E06    Finance           8   85000
# 7      E08    Finance           5   70000

# %%
conditions = [df['Salary']>=75000, ((df['Salary']>=50000)&(df['Salary']<=74999))]
choices = ['High', 'Medium']
df['SalaryLevel'] = np.select(conditions, choices, default='Low')

# %%
df
# Out:
#   Employee Department  Experience  Salary SalaryLevel
# 0      E01         IT           5   60000      Medium
# 1      E02         HR           3   45000         Low
# 2      E03         IT           7   75000        High
# 3      E04    Finance           4   65000      Medium
# 4      E05         HR           6   55000      Medium
# 5      E06    Finance           8   85000        High
# 6      E07         IT           2   48000         Low
# 7      E08    Finance           5   70000      Medium
